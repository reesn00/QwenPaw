# %%
# 下载模型
# !modelscope download --model unsloth/Qwen3.5-9B-GGUF mmproj-BF16.gguf Qwen3.5-9B-UD-Q6_K_XL.gguf --local_dir ./unsloth/Qwen3.5-9B-GGUF

# %%
 # !.\llama-server.exe  -m "F:\\modelscope\\Qwen\\unsloth\\Qwen3.5-9B-GGUF\\Qwen3.5-9B-UD-Q6_K_XL.gguf" --port 9090 --mmproj "F:\\modelscope\\Qwen\\unsloth\\Qwen3.5-9B-GGUF\\mmproj-BF16.gguf" --host 0.0.0.0 -c 163840 -ngl 999 -ctk q8_0 -ctv q8_0  --flash-attn on -np 2 -a Qwen3.5-9B-UD-Q6_K_XL
